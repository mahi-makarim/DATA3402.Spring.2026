# %% [markdown]
# # Lab 4- Object Oriented Programming
#
# For all of the exercises below, make sure you provide tests of your solutions.

# %% [markdown]
# 1. Write a "counter" class that can be incremented up to a specified maximum value, will print an error if an attempt is made to increment beyond that value, and allows reseting the counter.

# %%
class Counter:
    def __init__(self, maximum):
        if maximum < 0:
            raise ValueError("The maximum value must be non-negative")
        self.maximum = maximum
        self.value = 0
        
    def increment(self):
        if self.value >= self.maximum:
            print("Error: The counter has reached its maximum value.")
        else:
            self.value += 1
    def reset(self):
        self.value = 0
    
    def get_value(self):
        return self.value
    
# Test Code with maximum = 2

c = Counter(2)

print("Initial value:", c.get_value())
c.increment()
print("1st increment:", c.get_value())
c.increment()
print("2nd increment:", c.get_value()) 
c.increment() # This should trigger the value error.
c.reset()
print("After reset:", c.get_value())

# Took help from ChatGPT to generate the test code, as my original test code did not include the c before the functions.
# Out:
# Initial value: 0
# 1st increment: 1
# 2nd increment: 2
# Error: The counter has reached its maximum value.
# After reset: 0

# %% [markdown]
# 2. Copy and paste your solution to question 1 and modify it so that all the data held by the counter is private. Implement functions to check the value of the counter, check the maximum value, and check if the counter is at the maximum.

# %%
class Counter:
    def __init__(self, maximum):
        if maximum < 0:
            raise ValueError("The maximum value must be non-negative")
        self._maximum = maximum
        self._value = 0
        
    def increment(self):
        if self._value >= self._maximum:
            print("Error: The counter has reached its maximum value.")
        else:
            self._value += 1
    def reset(self):
        self._value = 0
    
    def get_value(self):
        return self._value
    
    def get_maximum(self):
        return self._maximum
    
    def is_at_maximum(self):
        return self._value == self._maximum
    
# Test code with maximum = 2

c = Counter(2)
print("Initial:", c.get_value())
print("Maximum:", c.get_maximum())
print("At maximum?", c.is_at_maximum())

c.increment()
print("After 1:", c.get_value())
print("At maximum?", c.is_at_maximum())

c.increment()
print("After 2:", c.get_value())
print("At maximum?", c.is_at_maximum())

c.increment() # This should trigger the value error.

c.reset()
print("After reset:", c.get_value())
print("At maximum?", c.is_at_maximum())


# Needed help from ChatGPT to explain the question to me, it helped by telling me to put the "." in "self._maximum".
# Out:
# Initial: 0
# Maximum: 2
# At maximum? False
# After 1: 1
# At maximum? False
# After 2: 2
# At maximum? True
# Error: The counter has reached its maximum value.
# After reset: 0
# At maximum? False

# %% [markdown]
# 3. Implement a class to represent a rectangle, holding the length, width, and $x$ and $y$ coordinates of a corner of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Rectangle:
    def __init__(self, length, width, x, y):
        if length <= 0 or width <= 0:
            raise ValueError("The length and width must be positive.")
            
        self.__length = length
        self.__width = width
        self.__x = x
        self.__y = y
        
    # Accessors
    def get_length(self):
        return self.__length
    
    def get_width(self):
        return self.__width
    
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y
    
    def area(self):
        return self.__length * self.__width # Calculating area
    
    def perimeter(self):
        return 2 * (self.__length + self.__width) # Calculating perimeter


# Test code
r = Rectangle(10, 4, 0, 0)

print("Length:", r.get_length())
print("Width:", r.get_width())
print("Coordinates:", (r.get_x(), r.get_y()))
print("Area:", r.area())
print("Perimeter:", r.perimeter())
# Out:
# Length: 10
# Width: 4
# Coordinates: (0, 0)
# Area: 40
# Perimeter: 28

# %% [markdown]
# 4. Implement a class to represent a circle, holding the radius and $x$ and $y$ coordinates of center of the object. Implement functions that compute the area and perimeter of the rectangle. Make all data members private and privide accessors to retrieve values of data members.

# %%
class Circle:
    def __init__(self, radius, x, y):
        if radius <= 0:
            raise ValueError("The radius must be positive.")
        
        self.__radius = radius
        self.__x = x
        self.__y = y

    def get_radius(self):
        return self.__radius
    
    def get_x(self):
        return self.__x
    
    def get_y(self):
        return self.__y

    def area(self): 
        return 3.14 * (self.__radius ** 2) # Calculating area, pi = 3.14
    
    def perimeter(self):
        return 2 * 3.14 * self.__radius # Calculating perimeter (circumference), pi = 3.14


# Test code
c = Circle(10, 2, -2)

print("Radius:", c.get_radius())
print("Center:", (c.get_x(), c.get_y()))
print("Area:", c.area())
print("Circumference:", c.perimeter())
# Out:
# Radius: 10
# Center: (2, -2)
# Area: 314.0
# Circumference: 62.800000000000004

# %% [markdown]
# 5. Implement a common base class for the classes implemented in 3 and 4 above which implements all common methods as not implemented functions (virtual). Re-implement your regtangle and circule classes to inherit from the base class and overload the functions accordingly.

# %%
class Shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y
    
    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y  # Shared accessors
    
    def area(self):
        raise NotImplementedError("Subclasses must implement area()")
    
    def perimeter(self):
        raise NotImplementedError("Subclasses must implement perimeter()")
        

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        if length <= 0 or width <= 0:
            raise ValueError("The length and width must be positive.")
        super().__init__(x, y) 
        self.__length = length
        self.__width = width

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)


class Circle(Shape):
    def __init__(self, radius, x, y):
        if radius <= 0:
            raise ValueError("Radius must be positive.")
        super().__init__(x, y) 
        self.__radius = radius

    # Accessor
    def get_radius(self):
        return self.__radius

    # Overridden methods
    def area(self):
        return 3.14 * self.__radius ** 2

    def perimeter(self):
        return 2 * 3.14 * self.__radius


# Test code
r = Rectangle(5, 5, 1, -1)
print("Rectangle:", r.get_length(), r.get_width(), r.get_x(), r.get_y(), r.area(), r.perimeter())

c = Circle(5, 1, -1)
print("Circle:", c.get_radius(), c.get_x(), c.get_y(), c.area(), c.perimeter())
# Out:
# Rectangle: 5 5 1 -1 25 20
# Circle: 5 1 -1 78.5 31.400000000000002

# %% [markdown]
# 6. Implement a triangle class analogous to the rectangle and circle in question 5.

# %%
# Triangle class using base and height
class Triangle(Shape):
    def __init__(self, base, height, x, y):
        if base <= 0 or height <= 0:
            raise ValueError("The base and height must be positive.")
        super().__init__(x, y)
        self._base = base
        self._height = height
        
    def get_base(self):
        return self._base
    
    def get_height(self):
        return self._height
    
    def area(self):
        return 0.5 * self._base * self._height # Calculating area
    
    def perimeter(self):
        hypotenuse = (self._base**2 + self._height**2)**0.5
        return self._base + self._height + hypotenuse                      
# Test Code
                             
t = Triangle(5, 5, 1, 1)
print("Base:", t.get_base())
print("Height:", t.get_height())
print("Coordinates:", (t.get_x(), t.get_y()))
print("Area:", t.area())
print("Perimeter:", t.perimeter())
# Out:
# Base: 5
# Height: 5
# Coordinates: (1, 1)
# Area: 12.5
# Perimeter: 17.071067811865476

# %% [markdown]
# 7. Add a function to the object classes, including the base, that returns a list of up to 16 pairs of  $x$ and $y$ points on the parameter of the object.

# %%
class Shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y
    
    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y  # Shared accessors
    
    def area(self):
        raise NotImplementedError("Subclasses must implement area()")
    
    def perimeter(self):
        raise NotImplementedError("Subclasses must implement perimeter()")
        
    def get_points(self):
        raise NotImplemented("Subclasses must be specified for points to be implemented.")
        

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        if length <= 0 or width <= 0:
            raise ValueError("The length and width must be positive.")
        super().__init__(x, y) 
        self.__length = length
        self.__width = width

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def area(self):
        return self.__length * self.__width

    def perimeter(self):
        return 2 * (self.__length + self.__width)
    
    def get_points(self):
        pts = []
        x, y = self.get_x(), self.get_y()
        l, w = self.get_length(), self.get_width()
        for i in range(4): pts.append((x + (i/4)*l, y))          # Four points per side, 16 in total
        for i in range(4): pts.append((x + l, y + (i/4)*w))      
        for i in range(4): pts.append((x + l - (i/4)*l, y + w))  
        for i in range(4): pts.append((x, y + w - (i/4)*w))      
        return pts


class Circle(Shape):
    def __init__(self, radius, x, y):
        if radius <= 0:
            raise ValueError("Radius must be positive.")
        super().__init__(x, y) 
        self.__radius = radius

    def get_radius(self):
        return self.__radius

    def area(self):
        return 3.14 * self.__radius ** 2

    def perimeter(self):
        return 2 * 3.14 * self.__radius
    
    def get_points(self):
        r = self.get_radius()
        x, y = self.get_x(), self.get_y()
        # Manual trig constants for 16 points without math library
        s1, s2, s3 = 0.383 * r, 0.707 * r, 0.924 * r
        return [
        (x+r, y), (x-r, y), (x, y+r), (x, y-r), # Cardinal
        (x+s2, y+s2), (x-s2, y+s2), (x+s2, y-s2), (x-s2, y-s2), # 45 deg
        (x+s1, y+s3), (x-s1, y+s3), (x+s1, y-s3), (x-s1, y-s3), # 67.5 deg
        (x+s3, y+s1), (x-s3, y+s1), (x+s3, y-s1), (x-s3, y-s1)  # 22.5 deg
        ]
        
class Triangle(Shape):
    def __init__(self, base, height, x, y):
        if base <= 0 or height <= 0:
            raise ValueError("The base and height must be positive.")
        super().__init__(x, y)
        self._base = base
        self._height = height
        
    def get_base(self):
        return self._base
    
    def get_height(self):
        return self._height
    
    def area(self):
        return 0.5 * self._base * self._height # Calculating area
    
    def perimeter(self):
        hypotenuse = (self._base**2 + self._height**2)**0.5
        return self._base + self._height + hypotenuse                                           
    
    def get_points(self):
        pts = []
        x, y = self.get_x(), self.get_y()
        b, h = self.get_base(), self.get_height()
        # Vertices for a right triangle: (x,y), (x+base, y), (x, y+height)
        v = [(x, y), (x + b, y), (x, y + h), (x, y)]
        for i in range(3):
            p1, p2 = v[i], v[i+1]
            for j in range(5):
                t = j / 5
                pts.append((p1[0] + (p2[0]-p1[0])*t, p1[1] + (p2[1]-p1[1])*t))
        pts.append(v[0])
        return pts
    
    
# Test Code
  
# Rectangle
rect = Rectangle(10, 5, 2, 0)

# Circle
circ = Circle(5, 10, 10)

# Triangle
tri = Triangle(6, 8, -4, 7)

# 2. Grouping them in a list
all_shapes = [rect, circ, tri]

print("Shape Details:")

for s in all_shapes:
    name = type(s).__name__
    print(f"--- {name} ---")
    print(f"Position: ({s.get_x()}, {s.get_y()})")
    print(f"Area: {s.area()}")
    
    # Rounding perimeter for cleaner output
    print(f"Perimeter: {round(s.perimeter(), 2)}")
    
    # Getting the list of 16 points
    points = s.get_points()
    print(f"Number of perimeter points: {len(points)}")
    
    # Printing the first 4 points as a sample
    print(f"First 4 points: {points[:4]}")
    print("-" * 25)

# 3. Test Error Handling
print("Errors:")
try:
    bad_circle = Circle(-5, 5, 5)
except ValueError as e:
    print(f"Caught expected error: {e}")
    
    
# For this code, I took extensive help of Gemini. I had it generate the code for determining circle's point as I was struggling to do it without using math library. By following circle's format, I was able to determine the method of determing the points for rectangles and triangles. In addition, I asked it to give me the format of how to complete the test code. Gemini told me to give a list of everything, rounding up the perimeter, listing the number of perimeters 16 points, and giving the first 4 as a sample.
# Out:
# Shape Details:
# --- Rectangle ---
# Position: (2, 0)
# Area: 50
# Perimeter: 30
# Number of perimeter points: 16
# First 4 points: [(2.0, 0), (4.5, 0), (7.0, 0), (9.5, 0)]
# -------------------------
# --- Circle ---
# Position: (10, 10)
# Area: 78.5
# Perimeter: 31.4
# Number of perimeter points: 16
# First 4 points: [(15, 10), (5, 10), (10, 15), (10, 5)]
# -------------------------
# --- Triangle ---
# Position: (-4, 7)
# Area: 24.0
# Perimeter: 24.0
# Number of perimeter points: 16
# First 4 points: [(-4.0, 7.0), (-2.8, 7.0), (-1.5999999999999996, 7.0), (-0.40000000000000036, 7.0)]
# -------------------------
# Errors:
# Caught expected error: Radius must be positive.

# %% [markdown]
# 8. Add a function to the object classes, including the base, that tests if a given set of $x$ and $y$ coordinates are inside of the object. You'll have to think through how to determine if a set of coordinates are inside an object for each object type.

# %%
class Shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y
    
    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y
    
    def area(self):
        raise NotImplemented("Subclasses must implement area()")
    
    def perimeter(self):
        raise NotImplemented("Subclasses must implement perimeter()")
        
    def get_points(self):
        raise NotImplemented("Subclasses must implement get_points()")
        
    def is_inside(self, px, py):
        raise NotImplemented("Subclasses must implement is_inside()")

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        if length <= 0 or width <= 0:
            raise ValueError("The length and width must be positive.")
        super().__init__(x, y) 
        self.__length = length
        self.__width = width

    def get_length(self): return self.__length
    def get_width(self): return self.__width
    def area(self): return self.__length * self.__width
    def perimeter(self): return 2 * (self.__length + self.__width)
    
    def get_points(self):
        pts = []
        x, y = self.get_x(), self.get_y()
        l, w = self.get_length(), self.get_width()
        for i in range(4): pts.append((x + (i/4)*l, y))
        for i in range(4): pts.append((x + l, y + (i/4)*w))
        for i in range(4): pts.append((x + l - (i/4)*l, y + w))
        for i in range(4): pts.append((x, y + w - (i/4)*w))
        return pts

    # Rectangle Logic: Point must be within the x and y boundaries
    def is_inside(self, px, py):
        x, y = self.get_x(), self.get_y()
        return (x <= px <= x + self.__length) and (y <= py <= y + self.__width)


class Circle(Shape):
    def __init__(self, radius, x, y):
        if radius <= 0:
            raise ValueError("Radius must be positive.")
        super().__init__(x, y) 
        self.__radius = radius

    def get_radius(self): return self.__radius
    def area(self): return 3.14 * self.__radius ** 2
    def perimeter(self): return 2 * 3.14 * self.__radius
    
    def get_points(self):
        r, x, y = self.get_radius(), self.get_x(), self.get_y()
        s1, s2, s3 = 0.383 * r, 0.707 * r, 0.924 * r
        return [
            (x+r, y), (x-r, y), (x, y+r), (x, y-r),
            (x+s2, y+s2), (x-s2, y+s2), (x+s2, y-s2), (x-s2, y-s2),
            (x+s1, y+s3), (x-s1, y+s3), (x+s1, y-s3), (x-s1, y-s3),
            (x+s3, y+s1), (x-s3, y+s1), (x+s3, y-s1), (x-s3, y-s1)
        ]

    # Circle Logic: Distance from center (x,y) to (px, py) <= radius
    def is_inside(self, px, py):
        dx = px - self.get_x()
        dy = py - self.get_y()
        return (dx**2 + dy**2) <= self.__radius**2
        
class Triangle(Shape):
    def __init__(self, base, height, x, y):
        if base <= 0 or height <= 0:
            raise ValueError("The base and height must be positive.")
        super().__init__(x, y)
        self._base = base
        self._height = height
        
    def get_base(self): return self._base
    def get_height(self): return self._height
    def area(self): return 0.5 * self._base * self._height 
    def perimeter(self): return self._base + self._height + (self._base**2 + self._height**2)**0.5
    
    def get_points(self):
        pts = []
        x, y = self.get_x(), self.get_y()
        b, h = self.get_base(), self.get_height()
        v = [(x, y), (x + b, y), (x, y + h), (x, y)]
        for i in range(3):
            p1, p2 = v[i], v[i+1]
            for j in range(5):
                t = j / 5
                pts.append((p1[0] + (p2[0]-p1[0])*t, p1[1] + (p2[1]-p1[1])*t))
        pts.append(v[0])
        return pts

    # Triangle Logic: Inside bounding box AND below the hypotenuse slope
    def is_inside(self, px, py):
        rel_x = px - self.get_x()
        rel_y = py - self.get_y()
        # Check if outside bounding box
        if rel_x < 0 or rel_x > self._base or rel_y < 0 or rel_y > self._height:
            return False
        # Check if below the hypotenuse line equation: (y/h) + (x/b) <= 1
        return (rel_y / self._height) + (rel_x / self._base) <= 1
    
    
# Test code

r = Rectangle(10, 5, 0, 0)
c = Circle(5, 0, 0)

print(f"Is (2, 2) in Rectangle? {r.is_inside(2, 2)}")    
print(f"Is (12, 2) in Rectangle? {r.is_inside(12, 2)}")  
print(f"Is (3, 3) in Circle? {c.is_inside(3, 3)}")       
print(f"Is (6, 0) in Circle? {c.is_inside(6, 0)}")
# Out:
# Is (2, 2) in Rectangle? True
# Is (12, 2) in Rectangle? False
# Is (3, 3) in Circle? True
# Is (6, 0) in Circle? False

# %% [markdown]
# 9. Add a function in the base class of the object classes that returns true/false testing that the object overlaps with another object.

# %%
class Shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y
    
    def get_x(self):
        return self.__x

    def get_y(self):
        return self.__y
    
    def area(self):
        raise NotImplemented("Subclasses must implement area()")
    
    def perimeter(self):
        raise NotImplemented("Subclasses must implement perimeter()")
        
    def get_points(self):
        raise NotImplemented("Subclasses must implement get_points()")
        
    def is_inside(self, px, py):
        raise NotImplemented("Subclasses must implement is_inside()")
    
    def overlaps(self, other):
        for px, py in self.get_points():
            if other.is_inside(px, py):
                return True
        
        for px, py in other.get_points():
            if self.is_inside(px, py):
                return True
                
        return False
    
    
class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        if length <= 0 or width <= 0:
            raise ValueError("The length and width must be positive.")
        super().__init__(x, y) 
        self.__length = length
        self.__width = width

    def get_length(self): return self.__length
    def get_width(self): return self.__width
    def area(self): return self.__length * self.__width
    def perimeter(self): return 2 * (self.__length + self.__width)
    
    def get_points(self):
        pts = []
        x, y = self.get_x(), self.get_y()
        l, w = self.get_length(), self.get_width()
        for i in range(4): pts.append((x + (i/4)*l, y))
        for i in range(4): pts.append((x + l, y + (i/4)*w))
        for i in range(4): pts.append((x + l - (i/4)*l, y + w))
        for i in range(4): pts.append((x, y + w - (i/4)*w))
        return pts

    # Rectangle Logic: Point must be within the x and y boundaries
    def is_inside(self, px, py):
        x, y = self.get_x(), self.get_y()
        return (x <= px <= x + self.__length) and (y <= py <= y + self.__width)


class Circle(Shape):
    def __init__(self, radius, x, y):
        if radius <= 0:
            raise ValueError("Radius must be positive.")
        super().__init__(x, y) 
        self.__radius = radius

    def get_radius(self): return self.__radius
    def area(self): return 3.14 * self.__radius ** 2
    def perimeter(self): return 2 * 3.14 * self.__radius
    
    def get_points(self):
        r, x, y = self.get_radius(), self.get_x(), self.get_y()
        s1, s2, s3 = 0.383 * r, 0.707 * r, 0.924 * r
        return [
            (x+r, y), (x-r, y), (x, y+r), (x, y-r),
            (x+s2, y+s2), (x-s2, y+s2), (x+s2, y-s2), (x-s2, y-s2),
            (x+s1, y+s3), (x-s1, y+s3), (x+s1, y-s3), (x-s1, y-s3),
            (x+s3, y+s1), (x-s3, y+s1), (x+s3, y-s1), (x-s3, y-s1)
        ]

    # Circle Logic: Distance from center (x,y) to (px, py) <= radius
    def is_inside(self, px, py):
        dx = px - self.get_x()
        dy = py - self.get_y()
        return (dx**2 + dy**2) <= self.__radius**2
        
class Triangle(Shape):
    def __init__(self, base, height, x, y):
        if base <= 0 or height <= 0:
            raise ValueError("The base and height must be positive.")
        super().__init__(x, y)
        self._base = base
        self._height = height
        
    def get_base(self): return self._base
    def get_height(self): return self._height
    def area(self): return 0.5 * self._base * self._height 
    def perimeter(self): return self._base + self._height + (self._base**2 + self._height**2)**0.5
    
    def get_points(self):
        pts = []
        x, y = self.get_x(), self.get_y()
        b, h = self.get_base(), self.get_height()
        v = [(x, y), (x + b, y), (x, y + h), (x, y)]
        for i in range(3):
            p1, p2 = v[i], v[i+1]
            for j in range(5):
                t = j / 5
                pts.append((p1[0] + (p2[0]-p1[0])*t, p1[1] + (p2[1]-p1[1])*t))
        pts.append(v[0])
        return pts

    # Triangle Logic: Inside bounding box AND below the hypotenuse slope
    def is_inside(self, px, py):
        rel_x = px - self.get_x()
        rel_y = py - self.get_y()
        # Check if outside bounding box
        if rel_x < 0 or rel_x > self._base or rel_y < 0 or rel_y > self._height:
            return False
        # Check if below the hypotenuse line equation: (y/h) + (x/b) <= 1
        return (rel_y / self._height) + (rel_x / self._base) <= 1
    
    
# Test code

r = Rectangle(10, 10, 0, 0)

c_overlap = Circle(5, 8, 8) 

c_far = Circle(2, 20, 20)

print(f"Does Rectangle overlap with Circle 1? {r.overlaps(c_overlap)}") 
print(f"Does Rectangle overlap with Circle 2? {r.overlaps(c_far)}")
# Out:
# Does Rectangle overlap with Circle 1? True
# Does Rectangle overlap with Circle 2? False

# %% [markdown]
# 10. Copy the `Canvas` class from lecture to in a python file creating a `paint` module. Copy your classes from above into the module and implement paint functions. Implement a `CompoundShape` class. Create a simple drawing demonstrating that all of your classes are working.

# %% [markdown]
# 11. Create a `RasterDrawing` class. Demonstrate that you can create a drawing made of several shapes, paint the drawing, modify the drawing, and paint it again.

# %%
# %%writefile paint.py

class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        # Empty canvas is a matrix with element being the "space" character
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        if 0 <= row < self.height and 0 <= col < self.width:
            self.data[row][col] = char

    def get_pixel(self, row, col):
        return self.data[row][col]
    
    def clear_canvas(self):
        self.data = [[' '] * self.width for i in range(self.height)]
            
    def display(self):
        print("\n".join(["".join(row) for row in self.data]))


class Shape:
    def __init__(self, x, y):
        self.__x = x
        self.__y = y
    
    def get_x(self): return self.__x
    def get_y(self): return self.__y
    
    def paint(self, canvas, char='*'):
        for r in range(canvas.height):
            for c in range(canvas.width):
                if self.is_inside(c, r):
                    canvas.set_pixel(r, c, char)
                                     
    def overlaps(self, other):
        for px, py in self.get_points():
            if other.is_inside(px, py): return True
        for px, py in other.get_points():
            if self.is_inside(px, py): return True
        return False

    def is_inside(self, px, py):
        raise NotImplementedError()
        
    def get_points(self):
        raise NotImplementedError()


class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y) 
        self.__length = length
        self.__width = width
        
    def is_inside(self, px, py):
        x, y = self.get_x(), self.get_y()
        return x <= px <= x + self.__length and y <= py <= y + self.__width
        
    def get_points(self):
        pts = []
        x, y, l, w = self.get_x(), self.get_y(), self.__length, self.__width
        for i in range(4): pts.append((x + (i/4)*l, y))
        for i in range(4): pts.append((x + l, y + (i/4)*w))
        for i in range(4): pts.append((x + l - (i/4)*l, y + w))
        for i in range(4): pts.append((x, y + w - (i/4)*w))
        return pts


class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__(x, y) 
        self.__radius = radius
        
    def is_inside(self, px, py):
        return (px - self.get_x())**2 + (py - self.get_y())**2 <= self.__radius**2
        
    def get_points(self):
        r, x, y = self.__radius, self.get_x(), self.get_y()
        s2 = 0.707 * r
        return [(x+r, y), (x-r, y), (x, y+r), (x, y-r), (x+s2, y+s2), (x-s2, y+s2)]


class Triangle(Shape):
    def __init__(self, base, height, x, y):
        super().__init__(x, y)
        self._base, self._height = base, height
        
                                     
    def is_inside(self, px, py):
        rel_x, rel_y = px - self.get_x(), py - self.get_y()
        if rel_x < 0 or rel_x > self._base or rel_y < 0 or rel_y > self._height: return False
        return (rel_y / self._height) + (rel_x / self._base) <= 1
        
    def get_points(self):
        pts = []
        x, y, b, h = self.get_x(), self.get_y(), self._base, self._height
        v = [(x, y), (x + b, y), (x, y + h), (x, y)]
        for i in range(3):
            p1, p2 = v[i], v[i+1]
            for j in range(5):
                t = j / 5
                pts.append((p1[0] + (p2[0]-p1[0])*t, p1[1] + (p2[1]-p1[1])*t))
        return pts


class CompoundShape(Shape):
    def __init__(self):
        super().__init__(0, 0)
        self.__shapes = []
        
    def add_shape(self, shape):
        self.__shapes.append(shape)
        
    def is_inside(self, px, py):
        for s in self.__shapes:
            if s.is_inside(px, py): return True
        return False
        
    def get_points(self):
        all_pts = []
        for s in self.__shapes: all_pts.extend(s.get_points())
        return all_pts
    
    
# Needed help from Gemini to understand the question, it recommended me to start the cote with a %%write.file.paint.py
# Out:
# Overwriting paint.py

# %%
from paint import Canvas, Rectangle, Circle, Triangle, CompoundShape

# 1. Setup
cv = Canvas(60, 25)

# 2. Build a House (CompoundShape)
house = CompoundShape()
house.add_shape(Rectangle(20, 10, 10, 12)) 
house.add_shape(Triangle(24, 6, 8, 6))      
house.add_shape(Rectangle(4, 6, 18, 16))   

# 3. Build a Sun
sun = Circle(3, 45, 5)

# 4. Paint
house.paint(cv, '#')
sun.paint(cv, 'O')

# 5. Display
cv.display()
# Out:
#
#
#                                              O
#                                            OOOOO
#                                            OOOOO
#                                           OOOOOOO
#         #########################          OOOOO
#         #####################              OOOOO
#         #################                    O
#         #############
#         #########
#         #####
#         # #####################
#           #####################
#           #####################
#           #####################
#           #####################
#           #####################
#           #####################
#           #####################
#           #####################
#           #####################
#           #####################

# %% [markdown]
# 12. Implement the ability to load/save raster drawings and demonstate that your method works. One way to implement this ability:
#
#    * Overload `__repr__` functions of all objects to return strings of the python code that would construct the object.
#
#    * In the save method of raster drawing class, store the representations into the file.
#    * Write a loader function that reads the file and uses `eval` to instantiate the object.
#
# For example:

# %%
# %%writefile paint.py

class Canvas:
    def __init__(self, width, height):
        self.width = width
        self.height = height
        self.data = [[' '] * width for i in range(height)]

    def set_pixel(self, row, col, char='*'):
        if 0 <= row < self.height and 0 <= col < self.width:
            self.data[row][col] = char

    def display(self):
        print("\n".join(["".join(row) for row in self.data]))

class Shape:
    def __init__(self, x, y):
        self._x = x
        self._y = y
    
    def paint(self, canvas, char='*'):
        for r in range(canvas.height):
            for c in range(canvas.width):
                if self.is_inside(c, r):
                    canvas.set_pixel(r, c, char)

class Rectangle(Shape):
    def __init__(self, length, width, x, y):
        super().__init__(x, y)
        self._l, self._w = length, width
    def is_inside(self, px, py):
        return self._x <= px <= self._x + self._l and self._y <= py <= self._y + self._w
    def __repr__(self):
        return f"Rectangle({self._l}, {self._w}, {self._x}, {self._y})"

class Circle(Shape):
    def __init__(self, radius, x, y):
        super().__init__(x, y)
        self._r = radius
    def is_inside(self, px, py):
        return (px - self._x)**2 + (py - self._y)**2 <= self._r**2
    def __repr__(self):
        return f"Circle({self._r}, {self._x}, {self._y})"

class Triangle(Shape):
    def __init__(self, base, height, x, y):
        super().__init__(x, y)
        self._b, self._h = base, height
    def is_inside(self, px, py):
        rel_x, rel_y = px - self._x, py - self._y
        if rel_x < 0 or rel_x > self._b or rel_y < 0 or rel_y > self._h: return False
        return (rel_y / self._h) + (rel_x / self._b) <= 1
    def __repr__(self):
        return f"Triangle({self._b}, {self._h}, {self._x}, {self._y})"

class RasterDrawing:
    def __init__(self, shape_list=None):
        self.shapes = shape_list if shape_list else []
    def add_shape(self, shape):
        self.shapes.append(shape)
    def paint(self, canvas, char='*'):
        for s in self.shapes: s.paint(canvas, char)
    def __repr__(self):
        return "RasterDrawing([" + ",".join([repr(s) for s in self.shapes]) + "])"
    def save(self, filename):
        with open(filename, "w") as f:
            f.write(self.__repr__())

def load_raster(filename):
    with open(filename, "r") as f:
        return eval(f.read())
# Out:
# Overwriting paint.py

# %%
# Test
from paint import Canvas, Rectangle, Circle, Triangle, RasterDrawing, load_raster

drawing = RasterDrawing()
drawing.add_shape(Rectangle(10, 5, 2, 2))
drawing.add_shape(Circle(4, 25, 10))
drawing.add_shape(Triangle(12, 6, 40, 2))
drawing.save("test_save.txt")
print("1. Saved drawing to test_save.txt")

with open("test_save.txt", "r") as f:
    print(f"2. File Content: {f.read()}")

reloaded = load_raster("test_save.txt")
print(f"3. Reloaded {len(reloaded.shapes)} shapes from file.")

cv = Canvas(60, 20)
reloaded.paint(cv, '*')
print("\n4. Final Visual Output:")
cv.display()

# "with open("test_save.txt", "r") as f: print(f"2. File Content: {f.read()}")" was generated with the help of Gemini.
# the test values were generated using Gemini as my values were not giving an output that fit on the screen.
# Out:
# 1. Saved drawing to test_save.txt
# 2. File Content: RasterDrawing([Rectangle(10, 5, 2, 2),Circle(4, 25, 10),Triangle(12, 6, 40, 2)])
# 3. Reloaded 3 shapes from file.
#
# 4. Final Visual Output:
#
#
#   ***********                           *************
#   ***********                           ***********
#   ***********                           *********
#   ***********                           *******
#   ***********            *              *****
#   ***********          *****            ***
#                       *******           *
#                       *******
#                      *********
#                       *******
#                       *******
#                        *****
#                          *

# %%
# Create an object and save it
from paint import Rectangle, Circle, Triangle, RasterDrawing

my_scene = RasterDrawing()

my_scene.add_shape(Rectangle(length=10, width=5, x=2, y=2))
my_scene.add_shape(Circle(radius=4, x=25, y=10))
my_scene.add_shape(Triangle(base=12, height=6, x=40, y=2))

my_scene.save("drawing_data.txt")

print("Object created and saved successfully to 'drawing_data.txt'!")
# Out:
# Object created and saved successfully to 'drawing_data.txt'!

# %%
# Check contents of the saved file

with open("drawing_data.txt", "r") as f:
    contents = f.read()

print("Step 2: The actual text stored in the file is:")
print("-" * 60)
print(contents)
print("-" * 60)
# Out:
# Step 2: The actual text stored in the file is:
# ------------------------------------------------------------
# RasterDrawing([Rectangle(10, 5, 2, 2),Circle(4, 25, 10),Triangle(12, 6, 40, 2)])
# ------------------------------------------------------------

# %%
# Load the object
from paint import load_raster


ff_reloaded = load_raster("drawing_data.txt")

print("Step 3: Object successfully reloaded from file.")
print(f"Verified Type: {type(ff_reloaded)}")
# Out:
# Step 3: Object successfully reloaded from file.
# Verified Type: <class 'paint.RasterDrawing'>
